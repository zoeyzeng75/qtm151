# %% [markdown]
# # QTM 151 - Quiz 1
#
# ### Print your name below

# %%
# Write your answer here

# %% [markdown]
# This quiz is open book.
#
# - You can use the lecture notes and the internet
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should NOT communicate with other students

# %% [markdown]
# Print the following message:
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here

# %% [markdown]
# Import the libraries "numpy", "matplotlib.pyplot", and "pandas"

# %%
# Write your answer here

# %% [markdown]
# (a) Transform a list of values and plot it
#
# - Create an array with the following values
# - `vec_x = [1, 2, 3, 4, 5, 6]`
# - Create a new vector `vec_y` with the following formula
# - $\qquad y = \sqrt{x} + 2$
# - Produce a line plot of `vec_y` against `vec_x`
# - Label the axes and the title
# - Change the line color to `blue`, `orange`, or `magenta` (you choose)
#
# - **Hint**: You can use the `numpy` functions

# %%
# Write your answer here

# %% [markdown]
# (b) IF/ELSE statements
#
# - Create two lists:
# - `list_animals = ["dog", "cat", "bird", "fish"]`
# - `list_mammals = ["human", "dog", "whale", "cat"]`
# - Create a new variable `pet = "fish"`
# - Create an if/else that tests whether `pet` is a mammal. Print a message if the test is true.
#
# - **Hint**: Use the `in` command to test whether an element is part of a list (see Lecture 4)

# %%
# Write your answer here

# %% [markdown]
# (c) Plot random variables
#
# - Let $n = 500$
# - Generate `vec_a` from a Poisson distribution with (lam = 3, size = n)
# - Generate `vec_b` from an Exponential distribution with (scale = 2, size = n)
# - Generate `vec_c` from a Binomial distribution with (n = 10, p = 0.4, size = n)
# - Plot two scatter plots: (`vec_b` vs `vec_a`) and (`vec_c` vs `vec_a`)
# - Label the axes and title
# - Each graph should have a different title
#
# - To get full points, plot the scatter plots on a single column using the `subplots` syntax (see Lecture 6)

# %%
# Write your answer here

# %% [markdown]
# (d) Create the following list of seasons:
#
# `list_seasons = ["Summer", "Winter"]`
#
# `list_warm_seasons = ["Spring", "Summer"]`
#
# Create a for-loop that checks whether each element of `list_seasons` is a warm season. Create a message with this result.
#
# The output generated by your loop should look like this:
#
# `"Summer is a warm season"`
#
# `"Winter is NOT a warm season"`
#
# - **Hint**: Use if/else statements inside the loop. You can use the command "in" (see Lecture 4) to test whether an element belongs to a list

# %%
# Write your answer here:

# %% [markdown]
# (e) Loop through different variables and compute statistics
#
# - Create a list with the `.csv` dataset names (including their relative subfolder `data_quiz/`)
# - Run a for-loop over the list of dataset names. Inside the loop:
#     - Read the corresponding `.csv` dataset.
#     - Print the mean of the variable `percent_ages0to14` in each dataset
#
# Note: This exercise tells you how much the proportion of the population that is between 0 and 14 has varied from year to year using real data from the World Development Index.

# %%
## Write your answer here:
